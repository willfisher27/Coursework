# %%
import pandas as pd
storms = pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/dplyr/storms.csv")

# %%
storms
# Out:
#        Unnamed: 0  name  year  month  day  hour   lat  long  \
# 0               1   Amy  1975      6   27     0  27.5 -79.0
# 1               2   Amy  1975      6   27     6  28.5 -79.0
# 2               3   Amy  1975      6   27    12  29.5 -79.0
# 3               4   Amy  1975      6   27    18  30.5 -79.0
# 4               5   Amy  1975      6   28     0  31.5 -78.8
# ...           ...   ...   ...    ...  ...   ...   ...   ...
# 11854       11855  Iota  2020     11   17    12  13.7 -84.7
# 11855       11856  Iota  2020     11   17    18  13.7 -85.7
# 11856       11857  Iota  2020     11   18     0  13.8 -86.7
# 11857       11858  Iota  2020     11   18     6  13.8 -87.8
# 11858       11859  Iota  2020     11   18    12  13.7 -89.0
#
#                     status  category  wind  pressure  \
# 0      tropical depression        -1    25      1013
# 1      tropical depression        -1    25      1013
# 2      tropical depression        -1    25      1013
# ...

# %%
for col in storms.columns:
    print(col, storms[col].dtype)
# Out:
# Unnamed: 0 int64
# name object
# year int64
# month int64
# day int64
# hour int64
# lat float64
# long float64
# status object
# category int64
# wind int64
# pressure int64
# tropicalstorm_force_diameter float64
# hurricane_force_diameter float64

# %%
# Out:
# str

# %%
names = storms['name'].unique().tolist()
for i in names:
    df = storms[storms['name']==i]
    if not df.isnull().values.any():
        print(i)
# Out:
# AL102004
# Otto
# Franklin
# Ten
# Lee
# Maria
# Nate
# Ophelia
# Philippe
# Nineteen
# Vince
# Beta
# Gamma
# Epsilon
# Zeta
# AL022006
# Ingrid
# Melissa
# Fifteen
# Ike
# Omar
# Sixteen
# Paloma
# One
# Fred
# Eight
# Ida
# Two
# Colin
# Five
# Fiona
# Igor
# Julia
# Paula
# Richard
# Shary
# Tomas
# Don
# Katia
# Al202011
# Rina
# Sean
# Kirk
# Oscar
# Patty
# Rafael
# Sandy
# Tony
# Andrea
# Dorian
# Fernand
# Gonzalo
# Nine
# Joaquin
# Ian
# Four
# Eleven
# Three
# Imelda
# Nestor
# Isaias
# Paulette
# Rene
# Sally
# Teddy
# Vicky
# Wilfred
# Eta
# Theta
# Iota

# %%
paloma = storms[storms['name']=='Paloma']

# %%
paloma.to_csv('paloma.csv', index=False)

# %%
paloma
# Out:
#       Unnamed: 0    name  year  month  day  hour   lat  long  \
# 8080        8081  Paloma  2008     11    5    18  13.7 -81.7
# 8081        8082  Paloma  2008     11    6     0  14.2 -82.0
# 8082        8083  Paloma  2008     11    6     6  14.8 -82.1
# 8083        8084  Paloma  2008     11    6    12  15.4 -82.0
# 8084        8085  Paloma  2008     11    6    18  16.1 -81.9
# 8085        8086  Paloma  2008     11    7     0  16.8 -81.8
# 8086        8087  Paloma  2008     11    7     6  17.4 -81.7
# 8087        8088  Paloma  2008     11    7    12  18.0 -81.6
# 8088        8089  Paloma  2008     11    7    18  18.6 -81.4
# 8089        8090  Paloma  2008     11    8     0  19.0 -81.0
# 8090        8091  Paloma  2008     11    8     6  19.4 -80.4
# 8091        8092  Paloma  2008     11    8    12  19.8 -79.6
# 8092        8093  Paloma  2008     11    8    18  20.2 -78.8
# 8093        8094  Paloma  2008     11    9     0  20.7 -78.0
# ...

# %%
import matplotlib.pyplot as plt
colors = ['orange', 'pink', 'red', 'maroon']
stats = ['tropical depression', 'tropical storm', 'hurricane']
for s in stats:
    df = paloma[paloma['status']==s]
    if s=='hurricane':
        for num in range(4):
            df2 = df[df['category']==num+1]
            plt.scatter(df2['wind'], df2['pressure'], color=colors[num], label='Category '+str(num+1)+' Hurricane')
    elif s=='tropical storm':
        plt.scatter(df['wind'], df['pressure'], color='gold', label='Tropical Storm (Category 0)')
    else:
        plt.scatter(df['wind'], df['pressure'], color='green', label='Tropical Depression (Category -1)')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel('Maximum Windspeed (knots)', fontsize=13)
plt.ylabel('Air Pressure at Center (millibars)', fontsize=13)
plt.title('Hurricane Paloma Pressure Versus Windspeed', fontsize=14)
plt.show()

# %%
import numpy as np
x = paloma['long']
y = paloma['lat']
plt.figure(figsize=(10,10))
plt.scatter(x, y, s=np.array(paloma['tropicalstorm_force_diameter'])*75, label='Tropical storm diameter')
plt.scatter(x, y, s=np.array(paloma['hurricane_force_diameter'])*75, label='Hurricane diameter')
plt.scatter(x, y, label='Location of storm center')
plt.axis('equal')
plt.xticks([-83, -82, -81, -80, -79, -78, -77])
plt.xlabel('Longitude (°E)', fontsize=14)
plt.ylabel('Latitude (°N)', fontsize=14)
plt.legend(fontsize=16, loc=2)
plt.grid(True)
plt.title('Path and Size of Hurricane Paloma', fontsize=18)
plt.show()

# %%
emp_data = pd.read_csv('Current_Employee_Names__Salaries__and_Position_Titles.csv')

# %%
emp_data
# Out:
#                       Name                              Job Titles  \
# 0        AARON,  JEFFERY M                                SERGEANT
# 1           AARON,  KARINA  POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2      ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 3        ABARCA,  EMMANUEL                        CONCRETE LABORER
# 4       ABARCA,  FRANCES J                          POLICE OFFICER
# ...                    ...                                     ...
# 30377   ZYLINSKA,  KLAUDIA                          POLICE OFFICER
# 30378   ZYMANTAS,  LAURA C                          POLICE OFFICER
# 30379    ZYMANTAS,  MARK E                          POLICE OFFICER
# 30380  ZYRKOWSKI,  CARLO E                          POLICE OFFICER
# 30381  ZYSKOWSKI,  DARIUSZ                 CHIEF DATA BASE ANALYST
#
#         Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0           POLICE                 F           Salary            NaN
# ...

# %%
salaried = emp_data[emp_data['Salary or Hourly']=='Salary']
deps = salaried['Department'].unique().tolist()
del deps[len(deps)-2]
paid = {}
for dep in deps:
    df = salaried[salaried['Department']==dep]
    paid[dep] = df['Annual Salary'].mean()
paid = sorted(paid.items(), key=lambda x: x[1], reverse=True)
x = [i[0] for i in paid]
y = [int(i[1]) for i in paid]

fig, (ax1, ax2) = plt.subplots(1,2, sharey=True, figsize=(10,7), constrained_layout=True)
plt.xlabel('Department', loc='left', fontsize=14)
plt.title('Highest and Lowest Average Chicago Government Salaries by Department')
ax1.bar(x[:10], height=y[:10])
ax1.set_xticklabels(x[:10], rotation='vertical')
ax1.set_title('10 Highest Average Departmental Salaries', fontsize=14)
ax1.set_ylabel('Salary ($)', fontsize=14)
ax2.bar(x[-10:], height=y[-10:])
ax2.set_xticklabels(x[-10:], rotation='vertical')
ax2.set_title('10 Lowest Average Departmental Salaries', fontsize=14)
plt.show()
# Out:
# /var/folders/wb/y3g3vkq50k195vj4vpqk7bc00000gn/T/ipykernel_3726/4189081776.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(x[:10], rotation='vertical')
# /var/folders/wb/y3g3vkq50k195vj4vpqk7bc00000gn/T/ipykernel_3726/4189081776.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(x[-10:], rotation='vertical')

# %%
len(deps)
# Out:
# 36
